# %% [markdown]
# Центр непрерывного образования
#
# # Программа «Python для автоматизации и анализа данных»
#
# Неделя 2 - 1
#
# *Татьяна Рогович, НИУ ВШЭ*
#
# # (∩｀-´)⊃━☆ﾟ.*･｡ﾟ Задачи

# %% [markdown]
# ## 1. Средний балл (списки)
#
# Дан список `student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)`. Выполните пункты ниже. Все выводы должны быть в формате "Средний балл студента: {средний балл}"
#
# 1. Выведите фамилию и имя Ивана в формате "Студент: {Фамилия}, {Имя}"
# 2. Выведите возраст Ивана, если сейчас 2020 год.
# 3. Напечатайте оценки Ивана через запятую.
# 1. Найдите средний балл Ивана, если оценки хранятся в списке внутри кортежа. Сумму элементов списка можно найти с помощью функции sum(). Выведите средний балл.
# 3. Если средняя оценка Ивана больше или равна 8, то он получает повышенную стипендию. Выведите True или False.

# %%
# ваше решение здесь

student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)

# Выведите фамилию и имя Ивана в формате "Студент: {Фамилия}, {Имя}"
print("Студент:",(student[0][5:]),(student[0][:4]))

# Выведите возраст Ивана, если сейчас 2020 год.
print("Возраст студента:",(2020-student[1]))

# Напечатайте оценки Ивана через запятую.
print("Оценки студента:",(student[2]))


# Найдите средний балл Ивана, если оценки хранятся в списке внутри кортежа. 
# Сумму элементов списка можно найти с помощью функции sum(). Выведите средний балл.
import math
avgmrk = math.floor(sum(student[2]) / len(student[2]))
print("Средний балл студента:",avgmrk)

# Если средняя оценка Ивана больше или равна 8, то он получает повышенную стипендию. Выведите True или False.
if avgmrk<8:
    print(False)
# Out:
# Студент: Питонов Иван
# Возраст студента: 19
# Оценки студента: [8, 7, 7, 9, 6]
# Средний балл студента: 7
# False

# %% [markdown]
# ## 2. Сортируем числа и строки (списки, сортировки, map())
# Дан список `numbers = [1, 1000, 1002124, 25, 10, 20, 351]`. Выполните следующие шаги. Для сортировок пользуйтесь функцией sorted().
#
# 1. Отсортируйте этот список по возрастанию и сохраните результат в переменную numbers_int_sorted
# 2. На основе оригинального списка numbers с помощью функции map создайте новый список, где вместо каждого числа будет строка ('1', '1000' и т.д.) и сохраните его в переменную numbers_str
# 3. Отсортируйте список numbers_str по возрастанию и сохраните результат в переменную numbers_str_sorted
# 4. Отсортийте список numbers_str по возрастанию с помощью ключа, который перед сортировкой представляет строки в виде целых чисел, и сохраните результат в переменную numbers_str_key_sorted
# 5. Выведите три отсортированных списка. Есть ли среди них одинаковые? Почему?

# %%
# ваше решение здесь
numbers = [1, 1000, 1002124, 25, 10, 20, 351]

# Отсортируйте этот список по возрастанию и сохраните результат в переменную numbers_int_sorted
numbers_int_sorted = numbers
numbers_int_sorted.sort()
print(numbers_int_sorted)

# На основе оригинального списка numbers с помощью функции map создайте новый список, 
# где вместо каждого числа будет строка ('1', '1000' и т.д.) и сохраните его в переменную numbers_str
import copy
numbers_str = copy.deepcopy(numbers)
numbers_str = list (map (str, numbers_str))
print(numbers_str)
print(type(numbers_str[0]))

# Отсортируйте список numbers_str по возрастанию и сохраните результат в переменную numbers_str_sorted
numbers_str_sorted = numbers_str
print(type(numbers_str_sorted[0]))
print(sorted(numbers_str_sorted))

# Отсортийте список numbers_str по возрастанию с помощью ключа, 
# который перед сортировкой представляет строки в виде целых чисел, 
# и сохраните результат в переменную numbers_str_key_sorted

numbers_str_key_sorted = sorted(numbers_str, key = str.upper)
print(numbers_str_key_sorted)


# Выведите три отсортированных списка. Есть ли среди них одинаковые? Почему?

print(numbers_str)
print(sorted(numbers_str_sorted))
print(numbers_str_key_sorted)
# ключ не влияет на элементы списка. Вероятно неправильно истрактовано задание
# Out:
# [1, 10, 20, 25, 351, 1000, 1002124]
# ['1', '10', '20', '25', '351', '1000', '1002124']
# <class 'str'>
# <class 'str'>
# ['1', '10', '1000', '1002124', '20', '25', '351']
# ['1', '10', '1000', '1002124', '20', '25', '351']
# ['1', '10', '20', '25', '351', '1000', '1002124']
# ['1', '10', '1000', '1002124', '20', '25', '351']
# ['1', '10', '1000', '1002124', '20', '25', '351']

# %% [markdown]
# ## 3. Количество различных чисел (списки и множества)
#
# Дан список чисел, который может содержать до 100000 чисел. Определите, сколько в нем встречается различных чисел.
#
# #### Пример 1
#
# ##### Ввод
#
# 1 2 3 2 1
#
# ##### Вывод
#
# 3
#
# #### Пример 2
# ##### Ввод
#
# 1 2 3 4 5 1 2 1 2 7 3
#
# ##### Вывод
# 6

# %%
# ваше решение здесь
raw_data = [123,323,23]
# если здесь оставляю пустой список - не работает. Если непустой работает. Почему?
raw_data = input()
data = list (map (int, raw_data.split()))
# проверка
print(type(data))
# продолжаем расчет
data_set=set(data)
data_fin = list(data_set)
print(len(data_fin))
# Out:
# 23 23 2 3 32
# <class 'list'>
# 4

# %% [markdown]
# ## 4. Факультативы (множества)
# Группа из 3 студентов пишет заявки на желаемые факультативы из списка: английский, немецкий, право, математика, сольфеджио. Факультатив откроют, если на него запишутся все студенты. Каждый студент может выбрать минимум один и максимум три факультатива. Нужно посчитать количество факультативов, которые откроются.
#
# *Пример*
#
# **Ввод:**
#
# английский сольфеджио право
# математика сольфеджио
# немецкий право
#
# **Вывод:**
#
# 0
#
# **Ввод:**
#
# математика немецкий право
# математика немецкий
# немецкий право математика
#
# **Вывод:**
# 2

# %%
# ваше решение здесь
choosed_fac1=["английский", "сольфеджио", "право", "математика", "сольфеджио", "немецкий", "право", "физика"]
choosed_fac2=["английский", "сольфеджио", "право", "математика", "сольфеджио", "немецкий", "право", "физика"]
choosed_fac3=["английский", "сольфеджио", "право", "математика", "сольфеджио", "немецкий", "право", "итальянский"]
choosed_fac1 = input()
choice1_listed = list(map(str, choosed_fac1.split()))
choosed_fac2 = input()
choice2_listed = list(map(str, choosed_fac2.split()))
choosed_fac3 = input()
choice3_listed = list(map(str, choosed_fac3.split()))

fac_intersection = set(choice1_listed) & set(choice2_listed) & set(choice3_listed)
print(len(fac_intersection))
# проверка
print(type(fac_intersection))
print(fac_intersection)
# Out:
# 234 34
# 234
# 234
# 1
# <class 'set'>
# {'234'}

# %% [markdown]
# Давайте модифицируем эту задачу, и представим, что только два студента выбирают факультативы, откроются факультативы, которые выбрал, хотя бы один студент. Но затем выясняется, что один из факультативов из списка отменили. Выводить будет через запятую те факультативы, которые откроются.
#
# *Пример*
# **Ввод:**
#
# математика немецкий право
# математика английский
# право
#
# **Вывод:**
# математика, немецкий, английский

# %%
# ваше решение здесь

choosed_fac1=["английский", "сольфеджио", "право", "математика", "сольфеджио", "немецкий", "право", "физика"]
choosed_fac2=["английский", "сольфеджио", "право", "математика", "сольфеджио", "немецкий", "право", "физика"]
choosed_fac1 = input()
choice1_listed = list(map(str, choosed_fac1.split()))
choosed_fac2 = input()
choice2_listed = list(map(str, choosed_fac2.split()))

fac_intersection = set(choice1_listed) & set(choice2_listed)

canceled_fac = input()
canceled_fac_listed = list (map (str, canceled_fac.split()))
final_fac_qty = fac_intersection - set(canceled_fac_listed)
print(len(final_fac_qty))

# проверка
print(type(final_fac_qty))
print(final_fac_qty)
# Out:
# 23 3 3 3 2
# 23
# 3
# 1
# <class 'set'>
# {'23'}

# %% [markdown]
# ## 5. Вложенные словари
#
# Вам дан словарь, содержащий в себе списки словарей. Напишите код, который выведет на экран 'разработчик' из списка ключа Windows в в первом словаре из списка 2.

# %%
dict_of_lists = {'Список1': [{'Python': 'язык программирования'}, {'R':'язык программирования', 'LaTEX' : 'язык верстки' }], 
                 'Список2' : [{'Windows' : ['операционная система', 'разработчик'], 'UNIX' : 'операционная система'},
                              {'IBM': ['компания-производитель', 'разработчик'], 'IPv6' : 'интернет-протокол' }]}
 
# ваше решение здесь

print(dict_of_lists["Список2"][0]["Windows"][1])
# Out:
# разработчик

# %% [markdown]
# ## 6. Срезы строк
#
# Напоминание про работу со строками:
#
# len(s) - определить длину строки s
#
# s[i] - получить i-ый символ строки (нумерация с нуля, i - положительное), в случае отрицательного i нумерация идет справа-налево, начиная с -1, например, s[-1] - это последний символ строки
#
# s[i:j] - получить все символы с i-го включительно по j-ый не включительно
#
# s[:i] - все символы до i-го не включительно
#
# s[i:] - все символы, начиная с i-го включительно
#
# s[i:j:k] - все символы с i-го включитель по j-ый не включительно с шагом k, если шаг отрицательный, то i должно указывать на символ стоящий правее, чем j
#
# **Задача:**
#
# Дана строка.
# 1. Сначала выведите третий символ этой строки (считая, что нумерация символов начинается с 1).
# 2. Во второй строке выведите предпоследний символ этой строки.
# 3. В третьей строке выведите первые пять символов этой строки.
# 4. В четвертой строке выведите всю строку, кроме последних двух символов.
# 5. В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0).
# 6. В шестой строке выведите все символы с нечетными индексами (считая, что индексация начинается с 0).
# 7. В седьмой строке выведите все символы в обратном порядке.
# 8. В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
# 9. В девятой строке выведите длину данной строки.
#
# **Ввод:**
# Abrakadabra
#
# **Вывод:**
#
# r
# r
# Abrak
# Abrakadab
# Arkdba
# baaar
# arbadakarbA
# abdkrA
# 11

# %%
# ваше решение здесь

s = "Abrakadabra"

# 1. Сначала выведите третий символ этой строки (считая, что нумерация символов начинается с 1).
print(s[2])
# 2. Во второй строке выведите предпоследний символ этой строки.
print(s[-2])
# 3. В третьей строке выведите первые пять символов этой строки.
print(s[:5])
# 4. В четвертой строке выведите всю строку, кроме последних двух символов.
print(s[:-2])
# 5. В пятой строке выведите все символы с четными индексами (считая, что индексация начинается с 0).
print(s[::2])
# 6. В шестой строке выведите все символы с нечетными индексами (считая, что индексация начинается с 0).
print(s[1::2])
# 7. В седьмой строке выведите все символы в обратном порядке.
print(s[::-1])
# 8. В восьмой строке выведите все символы строки через один в обратном порядке, начиная с последнего.
print(s[-1::-2])
# 9. В девятой строке выведите длину данной строки.
print(len(s))
# Out:
# r
# r
# Abrak
# Abrakadab
# Arkdba
# baaar
# arbadakarbA
# abdkrA
# 11

# %% [markdown]
# ## 7. Срезы списков
#
# Используя список `girls`, выведите на экран с помощью срезов следующие списки:
#
#     ["Виолетта", "Кассандра", "Вирджиния", "Амелия"]
#     ["Вирджиния", "Амелия", "Розамунда", "Янина", "Беатриса"]
#     ["Иветта", "Виолетта", "Вирджиния", "Амелия"]
#     ["Кассандра", "Амелия", "Розамунда"]

# %%
girls = ["Иветта", "Виолетта", "Кассандра", "Вирджиния", 
         "Амелия", "Розамунда", "Янина", "Беатриса"]

# решение здесь
#    ["Виолетта", "Кассандра", "Вирджиния", "Амелия"]
print(girls[1:5])
#    ["Вирджиния", "Амелия", "Розамунда", "Янина", "Беатриса"]
print(girls[3:])
#    ["Иветта", "Виолетта", "Вирджиния", "Амелия"]
b=(girls[0:2]) 
b.append(girls[3])
b.append(girls[4])
# явно можно сделать короче. Как обратиться к 2 разным срезам в одной строке?
print(b)
#    ["Кассандра", "Амелия", "Розамунда"]
f=(girls[2:5:2])
f.append(girls[5])
print(f)
# Out:
# ['Виолетта', 'Кассандра', 'Вирджиния', 'Амелия']
# ['Вирджиния', 'Амелия', 'Розамунда', 'Янина', 'Беатриса']
# ['Иветта', 'Виолетта', 'Вирджиния', 'Амелия']
# ['Кассандра', 'Амелия', 'Розамунда']

# %% [markdown]
# ## 8. Блок-схемы (условия)
#
# Реализуйте код для обеих блок-схем в условии задачи
# ![](img/1.png)

# %%
# ваше решение здесь
mark = 3
mark=int(input())
if mark == 10:
    print("Отлично")
elif mark<6:
    print("Плохо")
else:
    print("Это нормально")
# Out:
# -1
# Плохо

# %% [markdown]
# ![](img/2.png)

# %%
# ваше решение здесь
# тот же код. Вижу, что ветвь mark<6 была отдельная,но не понимаю в чем разница в логике
mark = 3
mark=int(input())
if mark == 10:
    print("Отлично")
elif mark<6:
    print("Плохо")
else:
    print("Это нормально")

# %% [markdown]
# ### 9. Сколько чисел совпадает? (условия)
#
# Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3 (если все совпадают), 2 (если два совпадает) или 0 (если все числа различны).
#
# **Формат ввода**
# Вводятся три целых числа
#
# **Формат вывода**
# Целое число

# %%
# ваше решение здесь

check = [1,2,3]
check = input()
listed = list(map(int, check.split()))
a = len(listed)
listed_set = set(listed)
b = len(listed_set)
c = a - b

# теперь условие
if c == 2:
    print("3")
elif c == 1:
    print("2")
elif c == 0:
    print("0")
# Out:
# 0 1 2
# 0
# 0

# %% [markdown]
# ### 10. Наименьший делитель
#
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.
#
# **Формат ввода**
# Вводится целое положительное число
#
# **Формат вывода**
# Выведите ответ на задачу
#
# **Пример**
#
# **Ввод**
# 15
#
# **Вывод**
# 3

# %%
# ваше решение здесь

num = int(input("Введите целое число >= 2: "))
delitel = 1
res = num / delitel

while type(res) != float:
    delitel += 1
print("Наименьший делитель: ", delitel)
# Out:
# Введите целое число >= 2: 55
# Наименьший делитель:  1

# %%
23
